# %%
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
preproc_file_path = Path(r'C:\Users\hornh\OneDrive\Dokumente\Uni\Info\MachineLearning\project_dev_repo\ml_dev_repo\data\preprocessed_frames\scaled_to_torso\02-24_jonas_swipe_left_preproc.csv')
df = pd.read_csv(preproc_file_path, delimiter=' *,', engine='python')
df
# Out:
#       Unnamed: 0  left_elbow_x_diff  left_elbow_y_diff  right_elbow_x_diff  \
# 0              0           0.015040          -0.011610            0.025830
# 1              1           0.006841           0.016937            0.040826
# 2              2           0.008336           0.024758            0.051117
# 3              3           0.014317           0.035566            0.064682
# 4              4           0.024521           0.052669            0.069421
# ...          ...                ...                ...                 ...
# 6748        6748          -0.953456          -0.203063           -0.328745
# 6749        6749          -1.015979          -0.150756           -0.346605
# 6750        6750          -1.010048          -0.182542           -0.375383
# 6751        6751          -0.740632          -1.327506           -0.628107
# 6752        6752          -0.682015          -1.298727           -0.574539
#
#       right_elbow_y_diff  left_wrist_x_diff  left_wrist_y_diff  \
# ...

# %%
fig, axs = plt.subplots(6, 1, figsize=(80, 50))
for i in range(6):
    axs[i].step(df.index[i*200:i*200 + 200], df.loc[i*200:i*200 + 200-1, 'right_wrist_x_cumsum_5'], where='mid', color='blue')
    axs[i].step(df.index[i*200:i*200 + 200], df.loc[i*200:i*200 + 200-1, 'right_wrist_x_cumsum_0'], where='mid', color='green')
    axs[i].plot(df.index[i*200:i*200 + 200], df.loc[i*200:i*200 + 200-1, 'gt_sl']*0.5)

# %%
preproc_file_path = Path(r'C:\Users\hornh\OneDrive\Dokumente\Uni\Info\MachineLearning\project_dev_repo\ml_dev_repo\data\preprocessed_frames\scaled_to_torso\02-24_jonas_rotate_right_preproc.csv')
df = pd.read_csv(preproc_file_path, delimiter=' *,', engine='python')
df
# Out:
#       Unnamed: 0  left_elbow_x_cumsum_0  left_elbow_x_cumsum_1  \
# 0              0               0.006910               0.000309
# 1              1              -0.006403               0.018839
# 2              2               0.024944               0.033160
# 3              3               0.008260               0.009153
# 4              4               0.000896              -0.027071
# ...          ...                    ...                    ...
# 8170        8170               0.004087               0.010066
# 8171        8171               0.005904              -0.012565
# 8172        8172              -0.018281              -0.020444
# 8173        8173              -0.002822              -0.094550
# 8174        8174              -0.084174              -0.088143
#
#       left_elbow_x_cumsum_2  left_elbow_x_cumsum_3  left_elbow_x_cumsum_4  \
# 0                  0.026330               0.034901               0.035827
# ...

# %%
fig, axs = plt.subplots(6, 1, figsize=(80, 50))
for i in range(6):
    axs[i].step(df.index[i*200:i*200 + 200], df.loc[i*200:i*200 + 200-1, 'right_wrist_x_cumsum_5'], where='mid', color='blue')
    axs[i].step(df.index[i*200:i*200 + 200], df.loc[i*200:i*200 + 200-1, 'right_wrist_y_cumsum_5'], where='mid', color='green')
    axs[i].plot(df.index[i*200:i*200 + 200], df.loc[i*200:i*200 + 200-1, 'gt_r'])

# %%
preproc_file_path = Path(r'C:\Users\hornh\OneDrive\Dokumente\Uni\Info\MachineLearning\project_dev_repo\ml_dev_repo\data\preprocessed_frames\with_angle\02-24_jonas_rotate_right_preproc.csv')
df = pd.read_csv(preproc_file_path, delimiter=' *,', engine='python')
df
# Out:
#       Unnamed: 0  left_elbow_x_cumsum_0  left_elbow_x_cumsum_1  \
# 0              0               0.006910               0.000309
# 1              1              -0.006403               0.018839
# 2              2               0.024944               0.033160
# 3              3               0.008260               0.009153
# 4              4               0.000896              -0.027071
# ...          ...                    ...                    ...
# 8170        8170               0.004087               0.010066
# 8171        8171               0.005904              -0.012565
# 8172        8172              -0.018281              -0.020444
# 8173        8173              -0.002822              -0.094550
# 8174        8174              -0.084174              -0.088143
#
#       left_elbow_x_cumsum_2  left_elbow_x_cumsum_3  left_elbow_x_cumsum_4  \
# 0                  0.026330               0.034901               0.035827
# ...

# %%
offset = 0
fig, axs = plt.subplots(10, 1, figsize=(80, 150))
for i in range(10):
    axs[i].step(df.index[i*200 + offset:i*200 + 200 + offset], df.loc[i*200 + offset:i*200 + 200-1 + offset, 'right_wrist_x_cumsum_0'], where='mid', color='blue')
    axs[i].step(df.index[i*200 + offset:i*200 + 200 + offset], df.loc[i*200 + offset:i*200 + 200-1 + offset, 'right_wrist_y_cumsum_0'], where='mid', color='green')
    axs[i].step(df.index[i*200:i*200 + 200], df.loc[i*200:i*200 + 200-1, 'right_forearm_angle_cumsum_5'], where='mid', color='red')
    axs[i].step(df.index[i*200:i*200 + 200], df.loc[i*200+6:i*200 + 200-1+6, 'right_forearm_angle_cumsum_0'], where='mid', color='black')
    axs[i].plot(df.index[i*200 + offset:i*200 + 200 + offset], df.loc[i*200 + offset:i*200 + 200-1 + offset, 'gt_r']*0.5)

# %%
a = df.loc[5*200:5*200 + 50-1, 'right_forearm_angle_cumsum_0']
df.loc[5*200:5*200 + 50-1, 'right_forearm_angle_cumsum_0'].plot()
# Out:
# <AxesSubplot:>

# %%
preproc_file_path = Path(r'C:\Users\hornh\OneDrive\Dokumente\Uni\Info\MachineLearning\project_dev_repo\ml_dev_repo\data\preprocessed_frames\with_angle\02-25_max_rotate_right_2022-02-28_18-52-43_preproc.csv')
df = pd.read_csv(preproc_file_path, delimiter=' *,', engine='python')
df
# Out:
#       Unnamed: 0  left_elbow_x_cumsum_0  left_elbow_x_cumsum_1  \
# 0              0              -0.910901              -0.681921
# 1              1               0.136547               0.448182
# 2              2               0.216753              -0.134838
# 3              3              -0.331121              -0.188934
# 4              4               0.192978               1.020484
# ...          ...                    ...                    ...
# 6059        6059               0.000041               0.000027
# 6060        6060              -0.000014              -0.000343
# 6061        6061              -0.000330              -0.000440
# 6062        6062              -0.000110              -0.000386
# 6063        6063              -0.000277              -0.000761
#
#       left_elbow_x_cumsum_2  left_elbow_x_cumsum_3  left_elbow_x_cumsum_4  \
# 0                 -0.159332              -1.007015              -0.643011
# ...

# %%
offset = 6000
fig, axs = plt.subplots(10, 1, figsize=(80, 150))
for i in range(10):
    axs[i].step(df.index[i*200 + offset:i*200 + 200 + offset], df.loc[i*200 + offset:i*200 + 200-1 + offset, 'right_wrist_x_cumsum_5'], where='mid', color='blue')
    axs[i].step(df.index[i*200 + offset:i*200 + 200 + offset], df.loc[i*200 + offset:i*200 + 200-1 + offset, 'right_wrist_y_cumsum_5'], where='mid', color='green')
    # axs[i].step(df.index[i*200:i*200 + 200], df.loc[i*200:i*200 + 200-1, 'right_forearm_angle_cumsum_5'], where='mid', color='red')
    # axs[i].step(df.index[i*200:i*200 + 200], df.loc[i*200:i*200 + 200-1, 'right_forearm_angle_cumsum_0'], where='mid', color='black')
    axs[i].plot(df.index[i*200 + offset:i*200 + 200 + offset], df.loc[i*200 + offset:i*200 + 200-1 + offset, 'gt_r']*0.5)

# %%
preproc_file_path = Path(r'C:\Users\hornh\OneDrive\Dokumente\Uni\Info\MachineLearning\project_dev_repo\ml_dev_repo\data\preprocessed_frames\with_angle\02-25_max_swipe_left_2022-02-28_19-29-13_preproc.csv')
df = pd.read_csv(preproc_file_path, delimiter=' *,', engine='python')

# %%
offset = 0000
fig, axs = plt.subplots(10, 1, figsize=(80, 150))
for i in range(10):
    axs[i].step(df.index[i*200 + offset:i*200 + 200 + offset], df.loc[i*200 + offset:i*200 + 200-1 + offset, 'right_wrist_x_cumsum_5'], where='mid', color='blue')
    axs[i].step(df.index[i*200 + offset:i*200 + 200 + offset], df.loc[i*200 + offset:i*200 + 200-1 + offset, 'right_wrist_y_cumsum_5'], where='mid', color='green')
    axs[i].step(df.index[i*200:i*200 + 200], df.loc[i*200:i*200 + 200-1, 'right_forearm_angle_cumsum_5'], where='mid', color='red')
    # axs[i].step(df.index[i*200:i*200 + 200], df.loc[i*200:i*200 + 200-1, 'right_forearm_angle_cumsum_0'], where='mid', color='black')
    axs[i].plot(df.index[i*200 + offset:i*200 + 200 + offset], df.loc[i*200 + offset:i*200 + 200-1 + offset, 'gt_sl']*0.5)

# %%
# preproc_file_path = Path(r'C:\Users\hornh\OneDrive\Dokumente\Uni\Info\MachineLearning\project_dev_repo\ml_dev_repo\data\preprocessed_frames\scaled_angle\02-25_max_swipe_left_2022-02-28_19-29-13_preproc.csv')
preproc_file_path = Path(r'C:\Users\hornh\OneDrive\Dokumente\Uni\Info\MachineLearning\project_dev_repo\ml_dev_repo\data\preprocessed_frames\scaled_angle\02-24_jonas_swipe_left_preproc.csv')
df = pd.read_csv(preproc_file_path, delimiter=' *,', engine='python')

# %%
offset = 0000
fig, axs = plt.subplots(10, 1, figsize=(80, 150))
for i in range(10):
    axs[i].step(df.index[i*200 + offset:i*200 + 200 + offset], df.loc[i*200 + offset:i*200 + 200-1 + offset, 'right_wrist_x_cumsum_5'], where='mid', color='blue')
    axs[i].step(df.index[i*200 + offset:i*200 + 200 + offset], df.loc[i*200 + offset:i*200 + 200-1 + offset, 'right_wrist_y_cumsum_5'], where='mid', color='green')
    axs[i].step(df.index[i*200:i*200 + 200], df.loc[i*200:i*200 + 200-1, 'right_forearm_angle_cumsum_5'], where='mid', color='red')
    # axs[i].step(df.index[i*200:i*200 + 200], df.loc[i*200:i*200 + 200-1, 'right_forearm_angle_cumsum_0'], where='mid', color='black')
    axs[i].plot(df.index[i*200 + offset:i*200 + 200 + offset], df.loc[i*200 + offset:i*200 + 200-1 + offset, 'gt_sl']*0.5)

# %%
preproc_file_path = Path(r'C:\Users\hornh\OneDrive\Dokumente\Uni\Info\MachineLearning\project_dev_repo\ml_dev_repo\data\preprocessed_frames\scaled_angle\02-25_max_rotate_right_2022-02-28_18-52-43_preproc.csv')
preproc_file_path = Path(r'C:\Users\hornh\OneDrive\Dokumente\Uni\Info\MachineLearning\project_dev_repo\ml_dev_repo\data\preprocessed_frames\scaled_angle\02-24_jonas_rotate_right_preproc.csv')
df = pd.read_csv(preproc_file_path, delimiter=' *,', engine='python')

# %%
offset = 0000
fig, axs = plt.subplots(10, 1, figsize=(80, 150))
for i in range(10):
    axs[i].step(df.index[i*200 + offset:i*200 + 200 + offset], df.loc[i*200 + offset:i*200 + 200-1 + offset, 'right_wrist_x_cumsum_5'], where='mid', color='blue')
    axs[i].step(df.index[i*200 + offset:i*200 + 200 + offset], df.loc[i*200 + offset:i*200 + 200-1 + offset, 'right_wrist_y_cumsum_5'], where='mid', color='green')
    axs[i].step(df.index[i*200:i*200 + 200], df.loc[i*200:i*200 + 200-1, 'right_forearm_angle_cumsum_5'], where='mid', color='red')
    # axs[i].step(df.index[i*200:i*200 + 200], df.loc[i*200:i*200 + 200-1, 'right_forearm_angle_cumsum_0'], where='mid', color='black')
    axs[i].plot(df.index[i*200 + offset:i*200 + 200 + offset], df.loc[i*200 + offset:i*200 + 200-1 + offset, 'gt_r']*0.5)
